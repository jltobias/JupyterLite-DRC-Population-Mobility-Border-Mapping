# %% [markdown]
# ## IOM Displacement Tracking Matrix (DTM)
# Add a dated DTM displacement or mobility product for the DRC from https://dtm.iom.int/democratic-republic-congo. Preserve product title, reference period, geography, retrieval date, and transformation steps before using it with health-access layers.

# %% [markdown]
# ## WorldMove human mobility
# Select and download city-level WorldMove data from https://fi.ee.tsinghua.edu.cn/worldmove/ before using mobility trajectories or flows. Preserve the selected city, package version, retrieval date, and conversion steps; do not treat the empty repository handoff layer as observed movement.

# %% [markdown]
# ## HydroRIVERS
# Use the browser-ready HydroRIVERS v1.0 DRC/Great Lakes extract as hydrographic context: https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/hydrosheds/hydrorivers-af-drc-great-lakes.geojson. The official product and complete download are documented at https://www.hydrosheds.org/products/hydrorivers.

# %% [markdown]
# # Health, shelter, and transport access layers
# Use this notebook to prepare context layers on both sides of a border corridor. Outbreak status must come from current WHO and national reporting, not from mobility alone.

# %%
overpass_query = '''[out:json][timeout:60];
area["ISO3166-1"="CD"]->.drc;
(nwr[amenity=hospital](area.drc); nwr[amenity=clinic](area.drc); nwr[aeroway=aerodrome](area.drc); nwr[highway=bus_stop](area.drc););
out center tags;'''
print(overpass_query)

# %% [markdown]
# Suggested layers: health facilities from healthsites.io, OpenStreetMap POIs, OSM, or HDX, administrative boundaries from GADM, African Bat Database occurrence records from Figshare, WHYMAP/WOKAM karst and cave layers, Overture building footprints, GHSL built-up surface, refugee and IDP sites from UNHCR/OCHA, roads and crossings from OSM/HOT, Natural Earth airports, airports and bus stations from OSM, population from WorldPop, and verified outbreak events from WHO or the relevant ministry. Include the DRC → South Sudan mobility corridor when comparing access in Ituri and neighboring border areas. Apply a date filter to every layer before comparing access. The browser-safe healthsites.io Ituri export is https://raw.githubusercontent.com/healthsites/drc-ebola-2026/master/healthsites_ituri_drc.geojson. GADM level-1 GeoJSON sources are listed at https://gadm.org/data.html. The African Bat Database record is https://figshare.com/articles/dataset/African_Bat_Database/26363308. Overture buildings guidance is https://docs.overturemaps.org/guides/buildings/. The OpenStreetMap POI sample is https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/osm/poi-goma-sample.geojson. The GHSL download portal is https://human-settlement.emergency.copernicus.eu/download.php. The Natural Earth airport source is https://www.naturalearthdata.com/downloads/10m-cultural-vectors/airports/.

# %%
required_fields = ['name', 'layer_type', 'latitude', 'longitude', 'reference_date', 'source', 'source_url']
required_fields

# %%
import pandas as pd
from IPython.display import IFrame, display

layer_catalog = pd.DataFrame([
    ('Mobility', 'IOM DTM displacement', 'select dated product from DTM portal'),
    ('Mobility', 'WorldMove trajectories', 'select city package from WorldMove portal'),
    ('Access', 'Healthsites.io facilities', 'repository-hosted Ituri GeoJSON'),
    ('Context', 'GADM boundaries / HydroRIVERS / airports', 'repository-hosted browser layers'),
    ('Context', 'African bats / karst / buildings / OSM POI', 'repository-hosted context layers'),
], columns=['theme', 'layer', 'status'])
display(layer_catalog)

# Open the same interactive map used by the project.
IFrame('../../maps/maplibre-drc-mobility.html', width='100%', height=650)

# %% [markdown]
# ## Scope and learning objectives
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## Data provenance and dates
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## Mobility measures and denominators
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## DRC to South Sudan corridor
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## Administrative boundary context
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## Health-facility access context
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## Population catchment assumptions
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## WorldMove package handoff
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## IOM DTM product handoff
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## HydroRIVERS context
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## African Bat Database context
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## WHYMAP karst and cave context
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## Overture building context
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## OpenStreetMap POI context
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %% [markdown]
# ## Airport and transport context
# Use this section to record the selected data release, geography, reference period, license, and limitations. Keep mapped context distinct from observed mobility or displacement evidence.

# %%
from IPython.display import IFrame
IFrame('../../maps/maplibre-drc-mobility.html', width='100%', height=600)

# %%
from IPython.display import IFrame
IFrame('../../maps/drc-mobility-map.html', width='100%', height=600)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# Demonstration buffer/catchment map in lon/lat coordinates; replace points with a dated facility extract.
facilities = {'Bunia': (30.22, 1.56), 'Aru': (30.82, 2.62), 'Mahagi': (30.95, 2.28)}
fig, ax = plt.subplots(figsize=(8, 5))
for name, (lon, lat) in facilities.items():
    ax.scatter(lon, lat, s=45, label=name)
    ax.add_patch(Circle((lon, lat), 0.18, fill=False, alpha=0.45))
ax.set(title='Health-facility buffers and population-catchment review', xlabel='Longitude', ylabel='Latitude')
ax.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

flow_demo = pd.DataFrame({'destination': ['Uganda', 'South Sudan', 'Rwanda', 'Burundi'], 'count': [12000, 2600, 8500, 6200]})
flow_demo.sort_values('count').plot.barh(x='destination', y='count', color='#d96c42', legend=False, title='Illustrative cross-border mobility')
plt.xlabel('Demonstration count; replace with dated observations')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Choropleth-ready administrative summary; join these values to GADM geometry by ADM_ID in a GIS workflow.
admin_summary = pd.DataFrame({'admin': ['Ituri', 'North Kivu', 'South Kivu', 'Upper Nile'], 'mobility_index': [0.82, 0.67, 0.54, 0.39]})
admin_summary.sort_values('mobility_index').plot.barh(x='admin', y='mobility_index', color=plt.cm.viridis(admin_summary.sort_values('mobility_index')['mobility_index']))
plt.title('Choropleth-ready mobility index by administrative area')
plt.xlabel('Standardized demonstration index')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Compare population captured by successive facility buffers; use population-grid data for a real catchment calculation.
radii_km = np.array([5, 10, 25, 50])
population_captured = np.array([18000, 42000, 98000, 165000])
plt.plot(radii_km, population_captured, marker='o', color='#147d7e')
plt.fill_between(radii_km, population_captured, alpha=0.15, color='#147d7e')
plt.title('Illustrative facility catchment sensitivity')
plt.xlabel('Buffer radius (km)')
plt.ylabel('Population within catchment')
plt.grid(alpha=0.25)
plt.show()

# %%
import pandas as pd

layer_catalog = pd.DataFrame([
    ('Mobility', 'IOM DTM', 'select dated DRC product'),
    ('Mobility', 'WorldMove', 'select city package'),
    ('Boundaries', 'GADM', 'repository snapshot'),
    ('Access', 'Healthsites.io', 'Ituri GeoJSON'),
    ('Hydrography', 'HydroRIVERS', 'DRC/Great Lakes extract'),
    ('Context', 'Bats, karst, buildings, POI, airports', 'repository layers'),
], columns=['theme', 'provider', 'status'])
layer_catalog

# %%
required_flow_fields = ['origin', 'destination', 'reference_date', 'count', 'source']
required_flow_fields

# %%
coordinate_checks = {'longitude_range': (-180, 180), 'latitude_range': (-90, 90), 'crs': 'EPSG:4326'}
coordinate_checks

# %%
from datetime import date
retrieval_date = date.today().isoformat()
retrieval_date

# %%
dtm_portal = 'https://dtm.iom.int/democratic-republic-congo'
{'provider': 'IOM DTM', 'url': dtm_portal, 'status': 'select dated product before analysis'}

# %%
worldmove_portal = 'https://fi.ee.tsinghua.edu.cn/worldmove/'
{'provider': 'WorldMove', 'url': worldmove_portal, 'status': 'select city package before analysis'}

# %%
gadm_countries = ['COD', 'UGA', 'RWA', 'BDI', 'SSD', 'ZMB', 'TZA', 'CAF', 'COG', 'AGO']
len(gadm_countries), gadm_countries

# %%
healthsites_url = 'https://raw.githubusercontent.com/healthsites/drc-ebola-2026/master/healthsites_ituri_drc.geojson'
healthsites_url

# %%
hydrorivers_url = 'https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/hydrosheds/hydrorivers-af-drc-great-lakes.geojson'
hydrorivers_url

# %%
source_urls = ['https://gadm.org/data.html', 'https://www.hydrosheds.org/products/hydrorivers', 'https://www.naturalearthdata.com/downloads/10m-cultural-vectors/airports/']
source_urls

# %%
buffer_radii_km = [5, 10, 25, 50]
assert all(radius > 0 for radius in buffer_radii_km)
buffer_radii_km

# %% [markdown]
# ## HDX Ebola cases and deaths
# The following cells load the complete HDX/INRB-UMIE CSV for dated case/death summaries. The mapped layer is a locality subset because the source CSV does not include coordinates; do not interpret these summaries as risk estimates or infer transmission from mobility.

# %%
import pandas as pd

ebola_url = 'https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/ebola/drc_ebola_cases_consolidated.csv'
ebola = pd.read_csv(ebola_url, parse_dates=['reference_date'])
ebola = ebola[ebola['measure'].isin(['cases', 'deaths'])].copy()
ebola[['location_name', 'reference_date', 'measure', 'case_classification', 'time_period', 'value']].head()

# %%
import matplotlib.pyplot as plt

weekly = ebola.groupby(['reference_date', 'measure'], as_index=False)['value'].sum().pivot(index='reference_date', columns='measure', values='value').fillna(0)
weekly.plot(figsize=(10, 4), color={'cases': '#d73027', 'deaths': '#542788'}, title='HDX DRC Ebola cases and deaths over time')
plt.ylabel('Reported cumulative value')
plt.xlabel('Reference date')
plt.grid(alpha=0.25)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

latest_date = ebola['reference_date'].max()
latest = ebola[ebola['reference_date'].eq(latest_date)].groupby(['location_name', 'measure'], dropna=False)['value'].sum().unstack(fill_value=0)
latest.sort_values('cases', ascending=True).tail(15).plot.barh(y=['cases', 'deaths'], figsize=(9, 6), color=['#d73027', '#542788'], title=f'Latest HDX Ebola values by locality ({latest_date.date()})')
plt.xlabel('Reported cumulative value')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## openAFRICA Ebola case figures
# Load the national and health-zone CSV resources from openAFRICA, retain their publication/reference dates, and compare them with HDX only after checking definitions and reporting periods.

# %%
import pandas as pd

openafrica_national_url = 'https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/openafrica/drc_national_timeseries.csv'
openafrica_zones_url = 'https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/openafrica/drc_zones_timeseries.csv'
openafrica_national = pd.read_csv(openafrica_national_url, parse_dates=['Report_date', 'Publication_date'])
openafrica_zones = pd.read_csv(openafrica_zones_url, parse_dates=['Date'])
openafrica_national.head(), openafrica_zones.head()

# %%
import matplotlib.pyplot as plt

openafrica_national.set_index('Report_date')[['Confirmed', 'Deaths']].plot(figsize=(10, 4), color=['#fc8d59', '#9e0142'], title='openAFRICA national Ebola case figures')
plt.ylabel('Reported cumulative value')
plt.xlabel('Report date')
plt.grid(alpha=0.25)
plt.tight_layout()
plt.show()

# %%
latest_openafrica_date = openafrica_zones['Date'].max()
latest_openafrica_zones = openafrica_zones[openafrica_zones['Date'].eq(latest_openafrica_date)].copy()
latest_openafrica_zones.set_index('Health Zone')[['Confirmed Cases', 'Confirmed Deaths']].sort_values('Confirmed Cases').tail(15).plot.barh(figsize=(9, 6), color=['#fc8d59', '#9e0142'], title=f'openAFRICA health-zone figures ({latest_openafrica_date.date()})')
plt.xlabel('Reported cumulative value')
plt.tight_layout()
plt.show()

# %%
latest_national = openafrica_national.sort_values('Report_date').iloc[-1]
openafrica_summary = {'report_date': latest_national['Report_date'].date().isoformat(), 'confirmed': latest_national['Confirmed'], 'deaths': latest_national['Deaths'], 'cfr_pct': latest_national['cfr_pct'], 'status': latest_national['Status']}
openafrica_summary
