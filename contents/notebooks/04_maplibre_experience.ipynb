# %% [markdown]
# ## IOM DTM displacement layer
# The standalone map includes an IOM DTM displacement handoff layer. Select a dated DRC product from https://dtm.iom.int/democratic-republic-congo and convert it before adding observations; the handoff remains empty until a specific product is selected.

# %% [markdown]
# ## HydroRIVERS layer
# The standalone MapLibre page loads the browser-ready HydroRIVERS v1.0 DRC/Great Lakes extract: https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/hydrosheds/hydrorivers-af-drc-great-lakes.geojson. See the official product page for the complete download and license: https://www.hydrosheds.org/products/hydrorivers.

# %% [markdown]
# ## WorldMove human mobility layer
# The standalone map includes a WorldMove handoff layer. Select a city and download the corresponding city package from the official portal before converting and adding trajectories: https://fi.ee.tsinghua.edu.cn/worldmove/.

# %% [markdown]
# # MapLibre experience: DRC mobility and border context
#
# This notebook documents the standalone MapLibre GL JS experience, including the DRC → South Sudan demonstration corridor. It uses the same demonstration GeoJSON as the GeoLibre Web launcher. The values are illustrative placeholders only.

# %%
from IPython.display import Markdown

data_url = 'https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/drc-mobility-demo.geojson'
healthsites_url = 'https://raw.githubusercontent.com/healthsites/drc-ebola-2026/master/healthsites_ituri_drc.geojson'
bat_url = 'https://jltobias.github.io/JupyterLite-DRC-Population-Mobility-Border-Mapping/data/african-bat-database.geojson'
buildings_url = 'https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/overture/buildings-goma-sample.geojson'
osm_poi_url = 'https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/osm/poi-goma-sample.geojson'
airports_url = 'https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/natural-earth/airports-10m.geojson'
ghsl_wms_url = 'https://geospatial.jrc.ec.europa.eu/geoserver/wms?service=WMS&request=GetMap&version=1.1.1&layers=africa_platform:ghsl_BuiltUpSurface_2020_3ss&styles=&format=image/png&transparent=true&srs=EPSG:3857&width=256&height=256&bbox={bbox-epsg-3857}'
gadm_urls = [f'https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/gadm/gadm41_{iso}_1.json' for iso in ['COD','UGA','RWA','BDI','SSD','ZMB','TZA','CAF','COG','AGO']]
whymap_urls = [f'https://raw.githubusercontent.com/jltobias/JupyterLite-DRC-Population-Mobility-Border-Mapping/main/data/whymap/geojson/{name}.geojson' for name in ['karst','caves','non_exposed_karst','springs']]
Markdown(f'[Demo GeoJSON data]({data_url})\n\n[Healthsites.io facility export]({healthsites_url})\n\n[African Bat Database GeoJSON layer]({bat_url})\n\n[Overture buildings sample]({buildings_url})\n\n[OpenStreetMap POI sample]({osm_poi_url})\n\n[Natural Earth airports]({airports_url})\n\n[GHSL 2020 built-up surface WMS]({ghsl_wms_url})\n\nGADM administrative boundary layers: {len(gadm_urls)} repository-hosted sources\n\nWHYMAP/WOKAM karst layers: {len(whymap_urls)} sources')

# %% [markdown]
# ## Launch the standalone MapLibre page
#
# The standalone HTML map is kept separate from GeoLibre Web so the two experiences can be compared directly.

# %%
Markdown('[Open the standalone MapLibre GL JS map](../../maps/maplibre-drc-mobility.html)')
